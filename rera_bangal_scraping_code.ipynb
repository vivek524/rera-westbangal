# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import os
import openpyxl
from openpyxl import load_workbook
url = "https://hira.wb.gov.in/district_project.php?dcode=0"
from selenium import webdriver
def driver_call(url):
        global driver
        #System.setProperty("webdriver.chrome.driver","/usr/bin/chromedriver");
        driver = webdriver.Chrome(executable_path="/home/anm/Downloads/chromedriver_linux64 (2)/chromedriver")
        #driver= webdriver.Chrome(executable_path="/home/anm/Downloads/chromedriver_linux64/chromedriver")
        driver.get(url)
        time.sleep(8)
def get_all_tables(soup):
    """Extracts and returns all tables in a soup object"""
    return soup.find_all("table")
def get_all_tables(soup):
    """Extracts and returns all tables in a soup object"""
    return soup.find_all("table")
def get_table_headers(table):
    """Given a table soup, returns all the headers"""
    headers = []
    for th in table.find("tr").find_all("th"):
        headers.append(th.text.strip())
    return headers
def get_table_rows(table):
    """Given a table, returns all its rows"""
    rows = []
    for tr in table.find_all("tr")[1:]:
        cells = []
        # grab all td tags in this table row
        tds = tr.find_all("td")
        if len(tds) == 0:
            # if no td tags, search for th tags
            # can be found especially in wikipedia tables below the table
            ths = tr.find_all("th")
            for th in ths:
                cells.append(th.text.strip())
        else:
            # use regular td tags
            for td in tds:
                cells.append(td.text.strip())
        rows.append(cells)
    return rows
def save_as_csv(table_name, headers, rows, i, writer):
    #pd.DataFrame(rows, columns=headers).to_csv(f"{table_name}.csv")
    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')
   



    # Write each dataframe to a different worksheet.
    pd.DataFrame(rows, columns=headers).to_excel(writer, sheet_name=f"Sheet-{i}")
    writer.save()
    writer.close()

# %%
z=[1,3,4,5,6,7,8,9]

# %%
z[0:1]
# Out:
# [1]

# %% [markdown]
# driver_call(url)
# Project_approved = []
#
#
# Project_details = []
# Project_details_list = []
# #RERAsoup = BeautifulSoup(driver.page_source, 'lxml')
#
# #table = soup.find('table', id = "projectDataTable")
# next_val=0
#
# time.sleep(1)
#
#
#            #try:
# for j in range(0,99):
#     print(j)
#     if j==0:
#         print("no click")
#     else:
#         elementID=driver.find_element_by_xpath('//*[@id="projectDataTable_next"]')
#         elementID.click()
#     time.sleep(5)
#     soup = BeautifulSoup(driver.page_source, 'lxml')
#     table = soup.find('table', id = "projectDataTable")
#     try:
#         for a in table.find_all('a', href=True):
#                         ntab_url = "https://hira.wb.gov.in/"+a['href']
#                         driver.execute_script('''window.open("","_blank");''')
#                         driver.switch_to.window(driver.window_handles[1])
#                         driver.get(ntab_url)
#                         time.sleep(10)
#                         #elementID=driver.find_element_by_xpath('//*[@id="projectDataTable"]/tbody/tr['+str(i)+']/td[3]/a')
#                         #elementID.click()
#                         #time.sleep(10)
#                         print('got the page')
#                         time.sleep(2)
#                         try: #Project_approved.append(driver.page_source)
#                             Project_name=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/h2').text
#                             print(Project_name)
#                             Project_Status=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[1]/strong').text
#
#                             Project_ID=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[2]').text
#                             Project_completion_date=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[3]').text
#                             HIRA_registration_no=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[4]').text
#                             Project_type=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li[1]/p/span/b').text
#                             Land_area=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li[2]/p/span/b').text
#                             Basement_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[1]/p/span/b').text
#                             Open_car_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[2]/p/span/b').text
#                             Covered_car_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[3]/p/span/b').text
#                             Mechanical_car_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[4]/p/span/b').text
#                             No_of_apartment=driver.find_element_by_xpath('//*[@id="page-top"]/section[2]/div/div[2]/div/div[4]/span[2]').text
#                             Location=driver.find_element_by_xpath('//*[@id="page-top"]/section[3]/div/div/div/div[1]/h5').text
#                                     #Map=driver.find_element_by_xpath('//*[@id="page-top"]/section[3]/div/div/div/div[2]/a').text
#                             soup = BeautifulSoup(driver.page_source , 'lxml')
#                             soup.find_all('a')
#                             mydivs = soup.find("section", {"class": "locationmap"}).select('a')
#                             maploc=mydivs[0]['href']
#                             time.sleep(10)
#                             Amenities=driver.find_element_by_xpath('//*[@id="page-top"]/section[5]').text
#                             Project_bangal=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[1]/div/div[2]/p').text
#                             Project_out_bangal=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[2]/div/div[2]/p').text
#                             Facility=driver.find_element_by_xpath('//*[@id="page-top"]/section[4]/div/div/div/div').text
#                             Ongoing=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[3]/div/div[2]/p[1]/span[1]').text
#                             Complited=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[4]/div/div[2]/p[1]/span[1]').text
#                             Registered_agent=driver.find_element_by_xpath('//*[@id="page-top"]/section[6]/div/div/div/div').text
#                             Consultant=driver.find_element_by_xpath('//*[@id="page-top"]/section[7]/div/div').text
#                             #Estimated_Cost_of_Construction=driver.find_element_by_css_selector("#ContentPlaceHolder1_txtecoc").get_attribute("value")
#                             #Estimated_Cost_of_Land=driver.find_element_by_css_selector("#ContentPlaceHolder1_txtecoc").get_attribute("value")
#                             #Project_Address=driver.find_element_by_css_selector("#ContentPlaceHolder1_AadharNumber").text
#
#
#                             Project_details = [Project_name,Project_Status,Project_ID,Project_completion_date,HIRA_registration_no,Project_type,
#                                                 Land_area,Basement_parking,Open_car_parking,Covered_car_parking,Mechanical_car_parking,Location,maploc,Amenities,Project_bangal,Project_out_bangal,
#                                                 Facility, Ongoing,Complited,Registered_agent,Consultant]
#
#                             Project_details_list.append(Project_details)
#
#                             time.sleep(10)
#
#                             driver.close()
#                             driver.switch_to.window(driver.window_handles[0])
#                         except:
#                             print("FAULT")
#     except:
#         print("FAIL")
#         driver.close()
#         driver.switch_to.window(driver.window_handles[0])
# j=j+1
#
# Project_details_list_df = pd.DataFrame(Project_details_list)
#
#
# Project_details_list_df.to_csv("/home/anm/project_bangal_detailFINAL.csv", index = False)
# print("Task Completed")

# %%
x=print("Enter Starting Page:", input())
# Out:
# vivek
# Enter Starting Page: vivek

# %%
driver_call(url)
Project_approved = []

           
Project_details = []
Project_details_list = []
#RERAsoup = BeautifulSoup(driver.page_source, 'lxml')

#table = soup.find('table', id = "projectDataTable")
next_val=0

time.sleep(1)
#S=print("Enter Starting Page:", input())
for i in range(0,):      
    elementID=driver.find_element_by_xpath('//*[@id="projectDataTable_next"]')
    elementID.click()
    time.sleep(2)
           #try:
for j in range(22,116):
    time.sleep(5)
    print(j)
    if j==0:
        print("no click")
    else:
        elementID=driver.find_element_by_xpath('//*[@id="projectDataTable_next"]')
        elementID.click()
    time.sleep(4)
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', id = "projectDataTable")
    try:           
        for a in table.find_all('a', href=True):
                        ntab_url = "https://hira.wb.gov.in/"+a['href']
                        driver.execute_script('''window.open("","_blank");''')
                        driver.switch_to.window(driver.window_handles[1])
                        driver.get(ntab_url)
                        time.sleep(8)
                        #elementID=driver.find_element_by_xpath('//*[@id="projectDataTable"]/tbody/tr['+str(i)+']/td[3]/a')
                        #elementID.click()
                        #time.sleep(10)
                        print('got the page')
                        time.sleep(2)
                        try: #Project_approved.append(driver.page_source)
                            Project_name=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/h2').text
                            print(Project_name)
                            Project_Status=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[1]/strong').text

                            Project_ID=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[2]').text
                            Project_completion_date=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[3]').text
                            HIRA_registration_no=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/ul/li[4]').text
                            Project_type=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li[1]/p/span/b').text
                            Land_area=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li[2]/p/span/b').text
                            Basement_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[1]/p/span/b').text
                            Open_car_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[2]/p/span/b').text
                            Covered_car_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[3]/p/span/b').text
                            Mechanical_car_parking=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[4]/p/span/b').text
                            No_of_apartment=driver.find_element_by_xpath('//*[@id="page-top"]/section[2]/div/div[2]/div/div[4]/span[2]').text
                            Location=driver.find_element_by_xpath('//*[@id="page-top"]/section[3]/div/div/div/div[1]/h5').text
                                    #Map=driver.find_element_by_xpath('//*[@id="page-top"]/section[3]/div/div/div/div[2]/a').text
                            soup = BeautifulSoup(driver.page_source , 'lxml')
                            soup.find_all('a')    
                            mydivs = soup.find("section", {"class": "locationmap"}).select('a')
                            maploc=mydivs[0]['href']
                            time.sleep(10)
                            Amenities=driver.find_element_by_xpath('//*[@id="page-top"]/section[5]').text
                            Project_bangal=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[1]/div/div[2]/p').text
                            Project_out_bangal=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[2]/div/div[2]/p').text
                            Facility=driver.find_element_by_xpath('//*[@id="page-top"]/section[4]/div/div/div/div').text
                            Ongoing=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[3]/div/div[2]/p[1]/span[1]').text
                            Complited=driver.find_element_by_xpath('//*[@id="page-top"]/section[9]/div/div[3]/div[4]/div/div[2]/p[1]/span[1]').text                                      
                            Registered_agent=driver.find_element_by_xpath('//*[@id="page-top"]/section[6]/div/div/div/div').text
                            Consultant=driver.find_element_by_xpath('//*[@id="page-top"]/section[7]/div/div').text
                            #Estimated_Cost_of_Construction=driver.find_element_by_css_selector("#ContentPlaceHolder1_txtecoc").get_attribute("value")
                            #Estimated_Cost_of_Land=driver.find_element_by_css_selector("#ContentPlaceHolder1_txtecoc").get_attribute("value")
                            #Project_Address=driver.find_element_by_css_selector("#ContentPlaceHolder1_AadharNumber").text
                            elementID=driver.find_element_by_xpath('//*[@id="right"]/a[2]/button')
                            elementID.click()
                            time.sleep(5)
                            driver.switch_to.window(driver.window_handles[1])
                            res_apart_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li/p/span').text
                            base_park_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[1]/p/span').text
                            open_car_par_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[2]/p/span').text
                            cover_car_par_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[3]/p/span').text
                            mech_car_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[4]/p/span').text
                            Project_details = [Project_name,Project_Status,Project_ID,Project_completion_date,HIRA_registration_no,Project_type,
                                                Land_area,Basement_parking,Open_car_parking,Covered_car_parking,Mechanical_car_parking,Location,maploc,Amenities,Project_bangal,Project_out_bangal,
                                                Facility, Ongoing,Complited,Registered_agent,Consultant,res_apart_book,base_park_book,open_car_par_book,cover_car_par_book,mech_car_book]
                            Project_details_list.append(Project_details)

                            time.sleep(5)

                            driver.close()
                            driver.switch_to.window(driver.window_handles[-1])
                            time.sleep(5)
                            driver.close()
                            driver.switch_to.window(driver.window_handles[0])
                        except:
                            print("FAULT")
    except:
        print("FAIL")
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
j=j+1

Project_details_list_df = pd.DataFrame(Project_details_list)
Project_details_list_df.columns =['Project_name','Project_Status','Project_ID','Project_completion_date','HIRA_registration_no','Project_type',
                                                'Land_area','Basement_parking','Open_car_parking','Covered_car_parking','Mechanical_car_parking','Location','maploc','Amenities','Project_bangal','Project_out_bangal',
                                                'Facility', 'Ongoing','Complited','Registered_agent','Consultant','res_apart_book','base_park_book','open_car_par_book','cover_car_par_book','mech_car_book']
Project_details_list_df.to_csv("/home/anm/final/project_bangal_detailFINAL.csv", index = False)
print("Task Completed")
# Out:
# 22
# got the page
# ASHRAY - I
# got the page
# GREENFIELD CITY PHASE IV
# got the page
# SANGATI PHASE I
# got the page
# ONE 10_PHASE I
# got the page
# TARANG TOWER I
# got the page
# BHATTACHARYA KUNJ
# got the page
# Z RESIDENCES
# got the page
# UTSODHAARA: TEESTA RESIDENTIAL PLOTS PHASE II
# FAULT
# got the page
# KRISHNAGAR SENTRUM - BLOCK 3
# got the page
# EMPEROR COMPLEX
# 23
# got the page
# KRISHNA KUNJA
# got the page
# PANTHANIWAS DOOARS , PHASE - II
# got the page
# VINAYAK GOLDEN ACRES
# got the page
# SHYAM RESIDENCY PHASE - II
# got the page
# SWABHUMI
# got the page
# SU CASA ROYAL
# got the page
# COSMOS VIEW
# got the page
# PRATISTHA EXOTICA
# got the page
# JAGADAMBA APARTMENT
# got the page
# PADMANABHYA ENCLAVE
# 24
# got the page
# PANCHNAI DILDHAN APARTMENT
# got the page
# RADHA KUNJA
# got the page
# UTSODHAARA: TEESTA RESIDENTIAL PLOTS PHASE I
# FAULT
# got the page
# SHYAM RESIDENCY PHASE - I
# got the page
# AKASH NEEL
# got the page
# SBM UPOHAR
# ...

# %%
Project_details_list_df = pd.DataFrame(Project_details_list)
Project_details_list_df.columns =['Project_name','Project_Status','Project_ID','Project_completion_date','HIRA_registration_no','Project_type',
                                                'Land_area','Basement_parking','Open_car_parking','Covered_car_parking','Mechanical_car_parking','Location','maploc','Amenities','Project_bangal','Project_out_bangal',
                                                 'Facility', 'Ongoing','Complited','Registered_agent','Consultant','res_apart_book','base_park_book','open_car_par_book','cover_car_par_book','mech_car_book']

# %%
Project_details_list_df
# Out:
#                  Project_name        Project_Status             Project_ID  \
# 0                  ASHRAY - I           Not Started  PROJECT ID: NPR-01008
# 1    GREENFIELD CITY PHASE IV           Not Started  PROJECT ID: NPR-00487
# 2             SANGATI PHASE I           Not Started  PROJECT ID: NPR-00671
# 3              ONE 10_PHASE I           Not Started  PROJECT ID: NPR-00426
# 4              TARANG TOWER I    Under Construction  PROJECT ID: NPR-00752
# ..                        ...                   ...                    ...
# 912        ARRJAVV SONARKELLA  Completed Without CC  PROJECT ID: NPR-00404
# 913        EDEN RICHMOND PARK  Completed Without CC  PROJECT ID: NPR-00931
# 914            ORIENTAL PALMS    Under Construction  PROJECT ID: NPR-00506
# 915            SHIVOHAM COURT  Completed Without CC  PROJECT ID: NPR-00585
# 916      ADVENTZ INFINITY @ 5  Completed Without CC  PROJECT ID: NPR-00197
#
#                  Project_completion_date  \
# ...

# %%
Project_details_list_df.to_csv("/home/anm/rera_bengal/final/project_bangal_detailFINAL_2.csv", index = False)

# %%
Project_details_list_df = pd.DataFrame(Project_details_list)

# %%
Project_details_list_df
# Out:
#                            0                   1                      2   \
# 0        NEW KOLKATA - SANGAM         Not Started  PROJECT ID: NPR-01014
# 1         ANANDVILLE PHASE II         Not Started  PROJECT ID: NPR-01412
# 2  "PRABHU ORCHARD " PHASE- I  Under Construction  PROJECT ID: NPR-00529
#
#                                     3   \
# 0  PROJECT COMPLETION DATE: 21-07-2030
# 1  PROJECT COMPLETION DATE: 31-03-2028
# 2  PROJECT COMPLETION DATE: 30-09-2027
#
#                                               4                       5   \
# 0  HIRA REGISTRATION NO.: HIRA/P/HOO/2019/000635             Residential
# 1  HIRA REGISTRATION NO.: HIRA/P/DAR/2020/000980  Residential,Commercial
# 2  HIRA REGISTRATION NO.: HIRA/P/SOU/2019/000718             Residential
#
#                            6              7              8     9   ...  \
# 0               76951 sq.mtr.  Not mentioned  Not mentioned  3796  ...
# ...

# %%
elementID=driver.find_element_by_xpath('//*[@id="right-handle"]')
elementID.click()

# %%
Project_details = [Project_name,Project_Status,Project_ID,Project_completion_date,HIRA_registration_no,Project_type,
                                                Land_area,Basement_parking,Open_car_parking,Covered_car_parking,Mechanical_car_parking,Location,maploc,Amenities,Project_bangal,Project_out_bangal,
                                                Facility, Ongoing,Complited,Registered_agent,Consultant,res_apart_book,base_park_book,open_car_par_book,cover_car_par_book,mech_car_book]

# %%
res_apart_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li/p/span')
base_park_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[1]/p/span')
open_car_par_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[2]/p/span')
cover_car_par_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[3]/p/span')
mech_car_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[4]/p/span')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db00f543fc30> in <module>
# ----> 1 res_apart_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[1]/li/p/span')
#       2 base_park_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[1]/p/span')
#       3 open_car_par_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[2]/p/span')
#       4 cover_car_par_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[3]/p/span')
#       5 mech_car_book=driver.find_element_by_xpath('//*[@id="page-top"]/section[1]/div/div/div/div/ul[2]/li[4]/p/span')
#
# NameError: name 'driver' is not defined

# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/home/anm/rera_bengal/final/project_bangal_detailFINAL_2.csv')

# %%
df['maploc']=df['maploc'].str.replace("http://www.google.com/maps/place/","")

# %%
df_1=df['maploc']

# %%
df_1=pd.DataFrame(df_1)

# %%
df_1
# Out:
#                                                  maploc
# 0     http://202.61.117.163/attachments/GridAttach/h...
# 1                                   22.294348,88.162703
# 2     http://202.61.117.163/attachments/GridAttach/h...
# 3                                   22.570000,88.460000
# 4     http://202.61.117.163/attachments/GridAttach/h...
# ...                                                 ...
# 1126  http://202.61.117.163/attachments/GridAttach/h...
# 1127                                22.584545,88.299545
# 1128                                22.576105,88.401123
# 1129                                22.676846,88.338509
# 1130                                22.290300,88.112800
#
# [1131 rows x 1 columns]

# %%
df_1= df_1['maploc'].str.split(",",expand=True)

# %%
df_1
# Out:
#                                                       0          1
# 0     http://202.61.117.163/attachments/GridAttach/h...       None
# 1                                             22.294348  88.162703
# 2     http://202.61.117.163/attachments/GridAttach/h...       None
# 3                                             22.570000  88.460000
# 4     http://202.61.117.163/attachments/GridAttach/h...       None
# ...                                                 ...        ...
# 1126  http://202.61.117.163/attachments/GridAttach/h...       None
# 1127                                          22.584545  88.299545
# 1128                                          22.576105  88.401123
# 1129                                          22.676846  88.338509
# 1130                                          22.290300  88.112800
#
# [1131 rows x 2 columns]

# %%
df_1.columns=['Latitute', 'Longitude']

# %%
df_1
# Out:
#                                                Latitute  Longitude
# 0     http://202.61.117.163/attachments/GridAttach/h...       None
# 1                                             22.294348  88.162703
# 2     http://202.61.117.163/attachments/GridAttach/h...       None
# 3                                             22.570000  88.460000
# 4     http://202.61.117.163/attachments/GridAttach/h...       None
# ...                                                 ...        ...
# 1126  http://202.61.117.163/attachments/GridAttach/h...       None
# 1127                                          22.584545  88.299545
# 1128                                          22.576105  88.401123
# 1129                                          22.676846  88.338509
# 1130                                          22.290300  88.112800
#
# [1131 rows x 2 columns]

# %%
len(df_1['Longitude'])
# Out:
# 1131

# %%
for i in range(len(df_1['Longitude'])):
    if df_1['Longitude'][i] == None:
        
        df_1['Latitute'][i]= None

# %%
df_1['Latitute'][0]==df_1['Latitute'][0].str.replace(df_1['Longitude'][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c68afb0adcf5> in <module>
# ----> 1 df_1['Latitute'][0]==df_1['Latitute'][0].str.replace(df_1['Longitude'][0])
#
# AttributeError: 'NoneType' object has no attribute 'str'

# %%
df_1
# Out:
#        Latitute  Longitude
# 0          None       None
# 1     22.294348  88.162703
# 2          None       None
# 3     22.570000  88.460000
# 4          None       None
# ...         ...        ...
# 1126       None       None
# 1127  22.584545  88.299545
# 1128  22.576105  88.401123
# 1129  22.676846  88.338509
# 1130  22.290300  88.112800
#
# [1131 rows x 2 columns]

# %%
df[['Longitude']]=df_1['Longitude']
df['Latitute']=df_1['Latitute']

# %%
df
# Out:
#                   Project_name      Project_Status             Project_ID  \
# 0                   ASHRAY - I         Not Started  PROJECT ID: NPR-01008
# 1     GREENFIELD CITY PHASE IV         Not Started  PROJECT ID: NPR-00487
# 2              SANGATI PHASE I         Not Started  PROJECT ID: NPR-00671
# 3               ONE 10_PHASE I         Not Started  PROJECT ID: NPR-00426
# 4               TARANG TOWER I  Under Construction  PROJECT ID: NPR-00752
# ...                        ...                 ...                    ...
# 1126            TARANG TOWER I  Under Construction  PROJECT ID: NPR-00752
# 1127         BHATTACHARYA KUNJ  Under Construction  PROJECT ID: NPR-01568
# 1128              Z RESIDENCES  Under Construction  PROJECT ID: NPR-00196
# 1129         PRATISTHA EXOTICA  Under Construction  PROJECT ID: NPR-00608
# 1130           EMPEROR COMPLEX  Under Construction  PROJECT ID: NPR-00925
#
#                   Project_completion_date  \
# ...

# %% [markdown]
# sub = 'NULL'
# df_1["Links"]= df_1[0].str.find(sub)

# %% [markdown]
# type(df_1["Links"])

# %% [markdown]
# count = 0
# count_l = []
# for i in df_1["Links"]:
#     count = count + 1
#     if i == 0:
#         count_l.append(count-1)
#
#
#
#
# print(count)

# %% [markdown]
# for i in count_l:
#     df_1 = df_1.replace(df_1[0][i], "http")
# df_1

# %% [markdown]
# df_12 = df_1
# for i in count_l:
#     df_12 = df_12.replace(df_12[0][i], None)

# %% [markdown]
# df_12

# %% [markdown]
# for i in count_l:
#     print(i)

# %%
df['Project_ID']=df['Project_ID'].str.replace("PROJECT ID: ","")

# %%
df['Project_completion_date']=df['Project_completion_date'].str.replace("PROJECT COMPLETION DATE: ","")

# %%
df['HIRA_registration_no']=df['HIRA_registration_no'].str.replace("HIRA REGISTRATION NO.:","")

# %%
df['Land_area']=df['Land_area'].str.replace("sq.mtr.","")

# %%
df['Registered_agent']=df['Registered_agent'].str.replace("Sl No. Agent","")
df['res_apart_book']=df['res_apart_book'].str.replace("Project Type\n","")
df['Consultant']=df['Consultant'].str.replace("CONSULTANTS\n","")
df['base_park_book']=df['base_park_book'].str.replace("Basement Parking\n","")
df['cover_car_par_book']=df['cover_car_par_book'].str.replace("Covered Car Parking\n","")
df['open_car_par_book']=df['open_car_par_book'].str.replace("Open Car Parking\n","")
df['mech_car_book']=df['mech_car_book'].str.replace("Mechanical Parking\n","")

# %%
df['Project_bangal']=df['Project_bangal'].str.replace("years of experience.","")

# %%
df['Project_out_bangal']=df['Project_out_bangal'].str.replace("years of experience.","")

# %%
df['base_park_book']=df['base_park_book'].str.replace("Basement Parking","")
df['open_car_par_book']=df['open_car_par_book'].str.replace("Open Car Parking","")
df['cover_car_par_book']=df['cover_car_par_book'].str.replace("Covered Car Parking","")
df['mech_car_book']=df['mech_car_book'].str.replace("Mechanical Parking","")

# %%
df
# Out:
#                   Project_name      Project_Status Project_ID  \
# 0                   ASHRAY - I         Not Started  NPR-01008
# 1     GREENFIELD CITY PHASE IV         Not Started  NPR-00487
# 2              SANGATI PHASE I         Not Started  NPR-00671
# 3               ONE 10_PHASE I         Not Started  NPR-00426
# 4               TARANG TOWER I  Under Construction  NPR-00752
# ...                        ...                 ...        ...
# 1126            TARANG TOWER I  Under Construction  NPR-00752
# 1127         BHATTACHARYA KUNJ  Under Construction  NPR-01568
# 1128              Z RESIDENCES  Under Construction  NPR-00196
# 1129         PRATISTHA EXOTICA  Under Construction  NPR-00608
# 1130           EMPEROR COMPLEX  Under Construction  NPR-00925
#
#      Project_completion_date     HIRA_registration_no            Project_type  \
# 0                 10-02-2024   HIRA/P/SOU/2019/000648  Residential,Commercial
# ...

# %%
proj_id=[]
m=["%.4d" % i for i in range(1,1132)]
for n in m:    
    proj_id.append('WB'+n)

# %%
df['Project_id']=proj_id

# %%
df.head(5)
# Out:
#                Project_name      Project_Status Project_ID  \
# 0                ASHRAY - I         Not Started  NPR-01008
# 1  GREENFIELD CITY PHASE IV         Not Started  NPR-00487
# 2           SANGATI PHASE I         Not Started  NPR-00671
# 3            ONE 10_PHASE I         Not Started  NPR-00426
# 4            TARANG TOWER I  Under Construction  NPR-00752
#
#   Project_completion_date     HIRA_registration_no            Project_type  \
# 0              10-02-2024   HIRA/P/SOU/2019/000648  Residential,Commercial
# 1              30-01-2024   HIRA/P/SOU/2020/000814             Residential
# 2              30-01-2024   HIRA/P/PAS/2019/000727             Residential
# 3              30-01-2024   HIRA/P/NOR/2018/000136             Residential
# 4              30-01-2024   HIRA/P/PAS/2020/000832             Residential
#
#   Land_area Basement_parking Open_car_parking Covered_car_parking  ...  \
# 0  662 ,49     Not mentioned    Not mentioned                  10  ...
# ...

# %%
df['Location'][0]
# Out:
# 'Sonarpur\nPS. Sonapur\nDist. South 24-Parganas\nPin 700147'

# %%
df_loc=df.Location.str.split('\nPin ',expand=True) 
df_loc=pd.DataFrame(df_loc)

# %%
df['Pincode']=df_loc[1]

# %%
df_loc
# Out:
#                                                       0       1
# 0        Sonarpur\nPS. Sonapur\nDist. South 24-Parganas  700147
# 1     Thakurpukur Mahestola\nPS. Mahestola\nDist. So...  700141
# 2     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  713305
# 3     Bidhannagar Municipal Corporation\nPS. New Tow...  700102
# 4     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  713305
# ...                                                 ...     ...
# 1126  SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  713305
# 1127  HOLDING NO. 58/3, BHATTACHARJEE PARA LANE L.R....  711104
# 1128  47 CANAL CIRCULAR ROAD\nKolkata\nPS. Phoolbaga...  700054
# 1129  92 K. G.T. ROAD\nSerampur Uttarpara\nPS. Uttar...  712232
# 1130  Budge Budge\nPS. Budge Budge\nDist. South 24-P...  700137
#
# [1131 rows x 2 columns]

# %%
df_loc=df_loc[0].str.split('\nDist. ',expand=True)

# %%
df_loc
# Out:
#                                                       0                  1
# 0                                 Sonarpur\nPS. Sonapur  South 24-Parganas
# 1                  Thakurpukur Mahestola\nPS. Mahestola  South 24-Parganas
# 2     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  Paschim Bardhaman
# 3       Bidhannagar Municipal Corporation\nPS. New Town  North 24-Parganas
# 4     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  Paschim Bardhaman
# ...                                                 ...                ...
# 1126  SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  Paschim Bardhaman
# 1127  HOLDING NO. 58/3, BHATTACHARJEE PARA LANE L.R....             Howrah
# 1128    47 CANAL CIRCULAR ROAD\nKolkata\nPS. Phoolbagan            Kolkata
# 1129  92 K. G.T. ROAD\nSerampur Uttarpara\nPS. Uttar...            Hooghly
# 1130                       Budge Budge\nPS. Budge Budge  South 24-Parganas
#
# [1131 rows x 2 columns]

# %%
df['District']=df_loc[1]

# %%
df_loc
# Out:
#                                                       0                  1
# 0                                 Sonarpur\nPS. Sonapur  South 24-Parganas
# 1                  Thakurpukur Mahestola\nPS. Mahestola  South 24-Parganas
# 2     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  Paschim Bardhaman
# 3       Bidhannagar Municipal Corporation\nPS. New Town  North 24-Parganas
# 4     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  Paschim Bardhaman
# ...                                                 ...                ...
# 1126  SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...  Paschim Bardhaman
# 1127  HOLDING NO. 58/3, BHATTACHARJEE PARA LANE L.R....             Howrah
# 1128    47 CANAL CIRCULAR ROAD\nKolkata\nPS. Phoolbagan            Kolkata
# 1129  92 K. G.T. ROAD\nSerampur Uttarpara\nPS. Uttar...            Hooghly
# 1130                       Budge Budge\nPS. Budge Budge  South 24-Parganas
#
# [1131 rows x 2 columns]

# %%
df_loc=df_loc[0].str.split('\nPS. ',expand=True)

# %%
df_loc
# Out:
#                                                       0                    1
# 0                                              Sonarpur              Sonapur
# 1                                 Thakurpukur Mahestola            Mahestola
# 2     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...       Asansol PS (S)
# 3                     Bidhannagar Municipal Corporation             New Town
# 4     SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...        Asansol PS(N)
# ...                                                 ...                  ...
# 1126  SHRISTINAGAR, ASANSOL SEN RALEIGH ROAD NEAR CE...        Asansol PS(N)
# 1127  HOLDING NO. 58/3, BHATTACHARJEE PARA LANE L.R....  Chatterjeehatt I.C.
# 1128                    47 CANAL CIRCULAR ROAD\nKolkata           Phoolbagan
# 1129                92 K. G.T. ROAD\nSerampur Uttarpara            Uttarpara
# 1130                                        Budge Budge          Budge Budge
#
# [1131 rows x 2 columns]

# %%
df['PS']=df_loc[1]
df['Locality']=df_loc[0]

# %%
df
# Out:
#                   Project_name      Project_Status Project_ID  \
# 0                   ASHRAY - I         Not Started  NPR-01008
# 1     GREENFIELD CITY PHASE IV         Not Started  NPR-00487
# 2              SANGATI PHASE I         Not Started  NPR-00671
# 3               ONE 10_PHASE I         Not Started  NPR-00426
# 4               TARANG TOWER I  Under Construction  NPR-00752
# ...                        ...                 ...        ...
# 1126            TARANG TOWER I  Under Construction  NPR-00752
# 1127         BHATTACHARYA KUNJ  Under Construction  NPR-01568
# 1128              Z RESIDENCES  Under Construction  NPR-00196
# 1129         PRATISTHA EXOTICA  Under Construction  NPR-00608
# 1130           EMPEROR COMPLEX  Under Construction  NPR-00925
#
#      Project_completion_date     HIRA_registration_no            Project_type  \
# 0                 10-02-2024   HIRA/P/SOU/2019/000648  Residential,Commercial
# ...

# %%
df.columns
# Out:
# Index(['Project_name', 'Project_Status', 'Project_ID',
#        'Project_completion_date', 'HIRA_registration_no', 'Project_type',
#        'Land_area', 'Basement_parking', 'Open_car_parking',
#        'Covered_car_parking', 'Mechanical_car_parking', 'Location', 'maploc',
#        'Amenities', 'Project_bangal', 'Project_out_bangal', 'Facility',
#        'Ongoing', 'Complited', 'Registered_agent', 'Consultant',
#        'res_apart_book', 'base_park_book', 'open_car_par_book',
#        'cover_car_par_book', 'mech_car_book', 'Longitude', 'Latitute',
#        'Project_id', 'Pincode', 'District', 'PS', 'Locality'],
#       dtype='object')

# %%
df_facility = df[['Project_id','Facility']]

# %%
df_facility.to_csv('/home/anm/rera_bengal/final/bangal_facility.csv', index=False)

# %%
df_facility['Facility'][1]
# Out:
# '  Drinking Water Facility\n  Emergency Evacuation Services\n  Fire Fighting Facility'

# %%
df_facility
# Out:
#      Project_id                                           Facility
# 0        WB0001                                                NaN
# 1        WB0002    Drinking Water Facility\n  Emergency Evacuat...
# 2        WB0003                                                NaN
# 3        WB0004    Emergency Evacuation Services\n  Drinking Wa...
# 4        WB0005                                                NaN
# ...         ...                                                ...
# 1126     WB1127                                                NaN
# 1127     WB1128    Drinking Water Facility\n  Fire Fighting Fac...
# 1128     WB1129    Drinking Water Facility\n  Fire Fighting Fac...
# 1129     WB1130    Emergency Evacuation Services\n  Fire Fighti...
# 1130     WB1131    Drinking Water Facility\n  Emergency Evacuat...
#
# [1131 rows x 2 columns]

# %%
df_facility1= pd.DataFrame(df_facility.Facility.str.split('\n ').tolist(), index=df_facility.Project_id).stack()

# %%
df_facility1
# Out:
# Project_id
# WB0002      0    [  Drinking Water Facility,  Emergency Evacuat...
# WB0004      0    [  Emergency Evacuation Services,  Drinking Wa...
# WB0006      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB0007      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB0009      0    [  Drinking Water Facility,  Emergency Evacuat...
#                                        ...
# WB1125      0    [  Emergency Evacuation Services,  Drinking Wa...
# WB1128      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB1129      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB1130      0    [  Emergency Evacuation Services,  Fire Fighti...
# WB1131      0    [  Drinking Water Facility,  Emergency Evacuat...
# Length: 511, dtype: object

# %%
df_facility1
# Out:
# Project_id
# WB0002      0    [  Drinking Water Facility,  Emergency Evacuat...
# WB0004      0    [  Emergency Evacuation Services,  Drinking Wa...
# WB0006      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB0007      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB0009      0    [  Drinking Water Facility,  Emergency Evacuat...
#                                        ...
# WB1125      0    [  Emergency Evacuation Services,  Drinking Wa...
# WB1128      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB1129      0    [  Drinking Water Facility,  Fire Fighting Fac...
# WB1130      0    [  Emergency Evacuation Services,  Fire Fighti...
# WB1131      0    [  Drinking Water Facility,  Emergency Evacuat...
# Length: 511, dtype: object

# %%
df_facility1 = df_facility1.reset_index([0, 'Project_id'])

# %%
df_facility1
# Out:
#     Project_id                                                  0
# 0       WB0002  [  Drinking Water Facility,  Emergency Evacuat...
# 1       WB0004  [  Emergency Evacuation Services,  Drinking Wa...
# 2       WB0006  [  Drinking Water Facility,  Fire Fighting Fac...
# 3       WB0007  [  Drinking Water Facility,  Fire Fighting Fac...
# 4       WB0009  [  Drinking Water Facility,  Emergency Evacuat...
# ..         ...                                                ...
# 506     WB1125  [  Emergency Evacuation Services,  Drinking Wa...
# 507     WB1128  [  Drinking Water Facility,  Fire Fighting Fac...
# 508     WB1129  [  Drinking Water Facility,  Fire Fighting Fac...
# 509     WB1130  [  Emergency Evacuation Services,  Fire Fighti...
# 510     WB1131  [  Drinking Water Facility,  Emergency Evacuat...
#
# [511 rows x 2 columns]

# %%
df_facility1.columns = ['Project_id', 'Facility']

# %%
df_facility1
# Out:
#     Project_id                                           Facility
# 0       WB0002  [  Drinking Water Facility,  Emergency Evacuat...
# 1       WB0004  [  Emergency Evacuation Services,  Drinking Wa...
# 2       WB0006  [  Drinking Water Facility,  Fire Fighting Fac...
# 3       WB0007  [  Drinking Water Facility,  Fire Fighting Fac...
# 4       WB0009  [  Drinking Water Facility,  Emergency Evacuat...
# ..         ...                                                ...
# 506     WB1125  [  Emergency Evacuation Services,  Drinking Wa...
# 507     WB1128  [  Drinking Water Facility,  Fire Fighting Fac...
# 508     WB1129  [  Drinking Water Facility,  Fire Fighting Fac...
# 509     WB1130  [  Emergency Evacuation Services,  Fire Fighti...
# 510     WB1131  [  Drinking Water Facility,  Emergency Evacuat...
#
# [511 rows x 2 columns]

# %%
df_facility1.to_csv('/home/anm/rera_bengal/final/project_bangal_facility.csv', index=False)

# %%
df_amenities=df[['Project_id','Amenities']]

# %%
df_amenities
# Out:
#      Project_id                                          Amenities
# 0        WB0001                                          AMENITIES
# 1        WB0002  AMENITIES\n  Access to common spaces\n  Access...
# 2        WB0003                                          AMENITIES
# 3        WB0004  AMENITIES\n  Access to the Project\n  Access t...
# 4        WB0005                                          AMENITIES
# ...         ...                                                ...
# 1126     WB1127                                          AMENITIES
# 1127     WB1128  AMENITIES\n  Access to common spaces\n  Access...
# 1128     WB1129  AMENITIES\n  Access to common spaces\n  Access...
# 1129     WB1130  AMENITIES\n  Access to the Project\n  Access t...
# 1130     WB1131  AMENITIES\n  Access to common spaces\n  Waste ...
#
# [1131 rows x 2 columns]

# %%
df_amenities['Amenities']=df_amenities['Amenities'].str.replace("AMENITIES\n ","")
# Out:
# /home/anm/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_amenities['Amenities']=df_amenities['Amenities'].str.replace("AMENITIES","")
# Out:
# /home/anm/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_amenities
# Out:
#      Project_id                                          Amenities
# 0        WB0001
# 1        WB0002   Access to common spaces\n  Access to the Proj...
# 2        WB0003
# 3        WB0004   Access to the Project\n  Access to common spa...
# 4        WB0005
# ...         ...                                                ...
# 1126     WB1127
# 1127     WB1128   Access to common spaces\n  Access to the Proj...
# 1128     WB1129   Access to common spaces\n  Access to the Project
# 1129     WB1130   Access to the Project\n  Access to common spa...
# 1130     WB1131   Access to common spaces\n  Waste disposal\n  ...
#
# [1131 rows x 2 columns]

# %%
df_amenities1= pd.DataFrame(df_amenities.Amenities.str.split('\n').tolist(), index=df_amenities.Project_id).stack()

# %%
df_amenities1
# Out:
# Project_id
# WB0001      0
# WB0002      0                              Access to common spaces
#             1                                Access to the Project
#             2      Design for electric supply including street ...
#             3                               Public health services
#                                        ...
# WB1130      1                              Access to common spaces
#             2                            Water supply arrangements
# WB1131      0                              Access to common spaces
#             1                                       Waste disposal
#             2                            Water supply arrangements
# Length: 2976, dtype: object

# %%
df_amenities1 = df_amenities1.reset_index([0, 'Project_id'])

# %%
df_amenities1.columns = ['Project_id', 'Amenities']

# %%
df_amenities1.to_csv('/home/anm/rera_bengal/final/project_bangal_aminities.csv', index=False)

# %%
df.columns
# Out:
# Index(['Project_name', 'Project_Status', 'Project_ID',
#        'Project_completion_date', 'HIRA_registration_no', 'Project_type',
#        'Land_area', 'Basement_parking', 'Open_car_parking',
#        'Covered_car_parking', 'Mechanical_car_parking', 'Location', 'maploc',
#        'Amenities', 'Project_bangal', 'Project_out_bangal', 'Facility',
#        'Ongoing', 'Complited', 'Registered_agent', 'Consultant',
#        'res_apart_book', 'base_park_book', 'open_car_par_book',
#        'cover_car_par_book', 'mech_car_book', 'Longitude', 'Latitute',
#        'Project_id', 'Pincode', 'District', 'PS', 'Locality'],
#       dtype='object')

# %%
df.drop(['Consultant','Registered_agent','res_apart_book','Facility','Location','Amenities','maploc'],inplace=True, axis=1)

# %%
df.to_csv('/home/anm/rera_bengal/final/project_bangal.csv', index=False)

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/home/anm/rera_bengal/final/project_bangal.csv')

# %%
df
# Out:
#                   Project_name      Project_Status Project_ID  \
# 0                   ASHRAY - I         Not Started  NPR-01008
# 1     GREENFIELD CITY PHASE IV         Not Started  NPR-00487
# 2              SANGATI PHASE I         Not Started  NPR-00671
# 3               ONE 10_PHASE I         Not Started  NPR-00426
# 4               TARANG TOWER I  Under Construction  NPR-00752
# ...                        ...                 ...        ...
# 1126            TARANG TOWER I  Under Construction  NPR-00752
# 1127         BHATTACHARYA KUNJ  Under Construction  NPR-01568
# 1128              Z RESIDENCES  Under Construction  NPR-00196
# 1129         PRATISTHA EXOTICA  Under Construction  NPR-00608
# 1130           EMPEROR COMPLEX  Under Construction  NPR-00925
#
#      Project_completion_date     HIRA_registration_no            Project_type  \
# 0                 10-02-2024   HIRA/P/SOU/2019/000648  Residential,Commercial
# ...

# %%
df1=df['Land_area']

# %%
df1=pd.DataFrame(df1)

# %%
df1=df1.assign(Land_area=df['Land_area'].str.split(',')).explode('Land_area')

# %%
df1
# Out:
#      Land_area
# 0         662
# 0          49
# 1         2997
# 2         4997
# 3        21159
# ...        ...
# 1126      2130
# 1127      1467
# 1128      9613
# 1129      3196
# 1130      1137
#
# [1401 rows x 1 columns]

# %%
df=df.assign(Project_type=df['Project_type'].str.split(',')).explode('Project_type')

# %%
df
# Out:
#                   Project_name      Project_Status Project_ID  \
# 0                   ASHRAY - I         Not Started  NPR-01008
# 0                   ASHRAY - I         Not Started  NPR-01008
# 1     GREENFIELD CITY PHASE IV         Not Started  NPR-00487
# 2              SANGATI PHASE I         Not Started  NPR-00671
# 3               ONE 10_PHASE I         Not Started  NPR-00426
# ...                        ...                 ...        ...
# 1126            TARANG TOWER I  Under Construction  NPR-00752
# 1127         BHATTACHARYA KUNJ  Under Construction  NPR-01568
# 1128              Z RESIDENCES  Under Construction  NPR-00196
# 1129         PRATISTHA EXOTICA  Under Construction  NPR-00608
# 1130           EMPEROR COMPLEX  Under Construction  NPR-00925
#
#      Project_completion_date     HIRA_registration_no Project_type Land_area  \
# 0                 10-02-2024   HIRA/P/SOU/2019/000648  Residential  662 ,49
# ...

# %%
df1['Land_area']
# Out:
# 0        662
# 0         49
# 1        2997
# 2        4997
# 3       21159
#         ...
# 1126     2130
# 1127     1467
# 1128     9613
# 1129     3196
# 1130     1137
# Name: Land_area, Length: 1401, dtype: object

# %%
df['Land_area']=df1['Land_area']

# %%
df
# Out:
#                   Project_name      Project_Status Project_ID  \
# 0                   ASHRAY - I         Not Started  NPR-01008
# 0                   ASHRAY - I         Not Started  NPR-01008
# 1     GREENFIELD CITY PHASE IV         Not Started  NPR-00487
# 2              SANGATI PHASE I         Not Started  NPR-00671
# 3               ONE 10_PHASE I         Not Started  NPR-00426
# ...                        ...                 ...        ...
# 1126            TARANG TOWER I  Under Construction  NPR-00752
# 1127         BHATTACHARYA KUNJ  Under Construction  NPR-01568
# 1128              Z RESIDENCES  Under Construction  NPR-00196
# 1129         PRATISTHA EXOTICA  Under Construction  NPR-00608
# 1130           EMPEROR COMPLEX  Under Construction  NPR-00925
#
#      Project_completion_date     HIRA_registration_no Project_type Land_area  \
# 0                 10-02-2024   HIRA/P/SOU/2019/000648  Residential      662
# ...

# %%
df.to_csv('/home/anm/rera_bengal/final/project_bangal_final.csv', index=False)

# %%
df_facility=pd.read_csv('/home/anm/rera_bengal/final/bangal_facility.csv')

# %%
df_facility
# Out:
#      Project_id                                           Facility
# 0        WB0001                                                NaN
# 1        WB0002    Drinking Water Facility\n  Emergency Evacuat...
# 2        WB0003                                                NaN
# 3        WB0004    Emergency Evacuation Services\n  Drinking Wa...
# 4        WB0005                                                NaN
# ...         ...                                                ...
# 1126     WB1127                                                NaN
# 1127     WB1128    Drinking Water Facility\n  Fire Fighting Fac...
# 1128     WB1129    Drinking Water Facility\n  Fire Fighting Fac...
# 1129     WB1130    Emergency Evacuation Services\n  Fire Fighti...
# 1130     WB1131    Drinking Water Facility\n  Emergency Evacuat...
#
# [1131 rows x 2 columns]

# %%
df_facility=df_facility.assign(Facility=df_facility['Facility'].str.split('\n')).explode('Facility')

# %%
df_facility
